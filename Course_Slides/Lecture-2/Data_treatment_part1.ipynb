# %% [markdown]
# ## MOVING A STEP FORWARD:
#
#    1) LEARNT HOW TO IMPORT DATA FROM VARIOUS SOURCES
#
#    2) DATA EXPLORING & CLEANING

# %%
#Libraries

import pandas as pd
import numpy as np

#dates package
from datetime import datetime as dt
from datetime import date, time, timedelta

#package to export your file to excel file 
#import openpyxl

#data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# Another way how you can import the data
#
#       using the url directly

# %%
#importing the data

#url = "http://data.insideairbnb.com/united-states/tx/austin/2021-07-08/visualisations/listings.csv"

data2 = pd.read_csv('listings.csv')
#data2 = pd.read_csv(url)


#pd.read_excel

# %% [markdown]
# #### Explorartory Data Analysis(EDA)
#        Intial Data Reviewing

# %%
#By default:
#head() - shows first five data rows



data2.head()
#data2.tail(10)

# view desired data rows
#data.head(10)

#type(data2)
# Out:
#      id                                               name  host_id  \
# 0  2265   Zen-East in the Heart of Austin (monthly rental)     2466
# 1  5245  Eco friendly, Colorful, Clean, Cozy monthly share     2466
# 2  5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 3  5636         Soco, Barton Springs Private Guest Cottage     7148
# 4  5769                                     NW Austin Room     8186
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0      Paddy                  NaN          78702     30.28     -97.71
# 1      Paddy                  NaN          78702     30.28     -97.71
# 2     Sylvia                  NaN          78702     30.26     -97.73
# 3      Peggy                  NaN          78704     30.25     -97.76
# 4  Elizabeth                  NaN          78729     30.46     -97.78
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#By default:
#tail() - shows last five data rows

data2.tail()

#view desired data rows
# Out:
#              id                                           name    host_id  \
# 10445  46281022  Locale | Rainey Street | 1BR Work from Locale    2370669
# 10446  46281034  Ideal Short Term Condo Location and Amenities     744383
# 10447  46281819            A place of your own | 1BR in Austin  359036978
# 10448  46281820       Entire apartment for you | 1BR in Austin  359036978
# 10449  46284246       Well-kept apartment home | 1BR in Austin  359036978
#
#       host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 10445    Locale                  NaN          78701     30.26     -97.74
# 10446   William                  NaN          78757     30.36     -97.74
# 10447       Kia                  NaN          78701     30.27     -97.74
# 10448       Kia                  NaN          78741     30.24     -97.72
# 10449       Kia                  NaN          78751     30.32     -97.72
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Export to excel (OPTIONAL: This is just an example to demonstrate to use export functions)

# %%
#Export the excel[OPTIONAL: This is just an example to demonstrate to use export functions]
#~/
#../
#data2.to_excel(r'Path to store the exported excel file\File Name.xlsx', sheet_name='Your sheet name', index = False)

#data2.to_excel(r'/Users/isha/Desktop/Exp_1.xlsx', sheet_name = 'sheet1', index = False)

# %%
#Data Dimensions 
data2.shape
# Out:
# (10450, 16)

# %% [markdown]
# #### Set and Reset index methods
# Please do not set the index unless you have cleaned this data. Hence this step is optional.

# %%
#data2 = data2.set_index('id')
#data2.reset_index()

# %% [markdown]
# ## Explore the **data problems**

# %% [markdown]
# ##### 1) Data Type Constraints

# %%
#This commands give info about your data
data2.info()
# %time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10450 entries, 0 to 10449
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10450 non-null  int64
#  1   name                            10450 non-null  object
#  2   host_id                         10450 non-null  int64
#  3   host_name                       10447 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10450 non-null  int64
#  6   latitude                        10450 non-null  float64
#  7   longitude                       10450 non-null  float64
#  8   room_type                       10450 non-null  object
#  9   price                           10450 non-null  int64
#  10  minimum_nights                  10450 non-null  int64
#  11  number_of_reviews               10450 non-null  int64
# ...

# %% [markdown]
# #### Descriptive statistics:
# summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.
#
# Analyzes both numeric and object series, as well as DataFrame column sets of mixed data types.

# %%
#compress the scientific notations
pd.set_option('display.float_format', '{:.2f}'.format) 

#descriptive stats 
data2.describe()
# Out:
#                id      host_id  neighbourhood_group  neighbourhood  latitude  \
# count    10450.00     10450.00                 0.00       10450.00  10450.00
# mean  25442191.33  94193437.20                  NaN       78722.78     30.28
# std   14573341.62 110546812.88                  NaN          20.76      0.06
# min       2265.00        23.00                  NaN       78701.00     30.08
# 25%   12849078.75  10595328.00                  NaN       78703.00     30.25
# 50%   24655329.00  43782388.00                  NaN       78721.00     30.27
# 75%   39274031.50 140301796.50                  NaN       78744.00     30.30
# max   46284246.00 374574667.00                  NaN       78759.00     30.52
#
#        longitude    price  minimum_nights  number_of_reviews  \
# count   10450.00 10450.00        10450.00           10450.00
# mean      -97.75   267.00            8.93              30.76
# std         0.06   610.35           24.64              66.24
# ...

# %% [markdown]
# ###  Did you realize the room_type data type?? ----> Why it is a object?

# %% [markdown]
# #### **Columns with mixed types are stored with the object dtype

# %%
#Object datatype not included by default
data2.describe(include = ['object','category','datetime64[ns]'])
# Out:
#                                               name host_name        room_type  \
# count                                        10450     10447            10450
# unique                                        9726      2700                4
# top     Stretch out. Work. Unwind. | 1BR in Austin       Kia  Entire home/apt
# freq                                            45       615             8148
#
#        last_review
# count         7643
# unique        1169
# top     2020-10-25
# freq           268

# %% [markdown]
# Did you see the room_type column above?
#
# Lets further investigate the column using pandas.unique()

# %%
#data['name'].unique()


data2['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %% [markdown]
# Convert the room_type feature to **category(not categorical) data type**
#
# We can use **.astype()** for data type conversion and we will store it another column in our DataFrame

# %%
#data['room_type_cate']= data['room_type'].astype('category') 

#data_frame['any col']
#data2.room
data2['room_type'] = data2['room_type'].astype('category') 

#data['room_type'].astype('category')
# %time
data2.info()
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10450 entries, 0 to 10449
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10450 non-null  int64
#  1   name                            10450 non-null  object
#  2   host_id                         10450 non-null  int64
#  3   host_name                       10447 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10450 non-null  int64
#  6   latitude                        10450 non-null  float64
#  7   longitude                       10450 non-null  float64
#  8   room_type                       10450 non-null  category
#  9   price                           10450 non-null  int64
#  10  minimum_nights                  10450 non-null  int64
# ...

# %%
# Two ways to check if the conversion is done 
#To make sure that the data type is converted(optional)

#Way-1
#data2.dtypes

#Way-2
#assert data2['last_review'].dtype == 'datetime64[ns]'

# %%
#room_type  description 
print(data2.room_type.describe())
# Out:
# count               10450
# unique                  4
# top       Entire home/apt
# freq                 8148
# Name: room_type, dtype: object

# %% [markdown]
# ## Your turn!!!!

# %% [markdown]
# ###### Lets checkout what other data type can be transformed such that we can make our data clean

# %% [markdown]
# ##### Another data-type important one is the **date

# %%
#Suppose we want to check the date range for a last_review
#data[]/data.col_name: access the columns in dataframe

data2.info()
#%%time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10450 entries, 0 to 10449
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10450 non-null  int64
#  1   name                            10450 non-null  object
#  2   host_id                         10450 non-null  int64
#  3   host_name                       10447 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10450 non-null  int64
#  6   latitude                        10450 non-null  float64
#  7   longitude                       10450 non-null  float64
#  8   room_type                       10450 non-null  category
#  9   price                           10450 non-null  int64
#  10  minimum_nights                  10450 non-null  int64
#  11  number_of_reviews               10450 non-null  int64
# ...

# %% [markdown]
# You cannot apply the .info() method to a series(means: to single column)

# %%
#Lets visualize the last_review column
#import warnings
#import matplotlib.pyplot as plt

plt.hist(data2['last_review'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 5
#       1 #Lets visualize the last_review column
#       2 #import warnings
#       3 #import matplotlib.pyplot as plt
# ----> 5 plt.hist(data2['last_review'])
#       6 plt.show()
#
# File ~/anaconda3/envs/myenv/lib/python3.11/site-packages/matplotlib/pyplot.py:2645, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2639 @_copy_docstring_and_deprecators(Axes.hist)
#    2640 def hist(
#    2641         x, bins=None, range=None, density=False, weights=None,
#    2642         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
# ...

# %% [markdown]
# ##### Error for the above will as follows:
# TypeError: 'value' must be an instance of str or bytes, not a float

# %% [markdown]
# ###### Problem: last_review:object

# %% [markdown]
# ##### Solution:   data2['last_review'] = data2[last_review].astype('????')   ---> doesn't work that way

# %% [markdown]
# ### Correct way:  We have `convert it to **datetime** object in pandas

# %%
#data2.describe(include = '')
dt.today()
# Out:
# datetime.datetime(2024, 6, 6, 13, 12, 56, 982090)

# %%
#library 
#import datetime as dt

#data2.name_of_col

data2['last_review'] = pd.to_datetime(data2['last_review'])

#pd.to_datetime(data2['last_review'])

#data2['last_review'] = data2['last_review']
#data2.info()

# %%
#Let's visualize it again
import matplotlib.pyplot as plt

plt.hist(data2['last_review'])
plt.xlabel('Last Review')
plt.ylabel('Index')
plt.title('Number of reviews per year')
plt.show()

# %%
import plotly
import plotly.express as px
import nbformat as nb
fig = px.line(data2, y='last_review')
fig.update_layout(title='Line Chart using Plotly')

fig.show()

# %% [markdown]
# ###### Incase if you want to ignore warnings:
#
# import warnings
# warnings.filterwarnings('ignore')

# %%
#This confirms there is not an issue for the data range 
#data2['last_review'].max()

# %% [markdown]
# ##### 2) Data Range Problems

# %%
#Lets create an example of numeric data
#import numpy as np
#import pandas as pd
#np.random.seed(2000000) 
#using np.random.randint: to get the random values
salary = np.random.randint(4000,10000,size=(10))
salary



#pd.DataFram: to create a dataframe

salary_sample = pd.DataFrame(salary, columns =['sal'])
salary_sample
# Out:
#     sal
# 0  5619
# 1  6083
# 2  9415
# 3  6307
# 4  5440
# 5  9257
# 6  8182
# 7  8070
# 8  5607
# 9  4553

# %% [markdown]
# ###### For example:
#          Company database has a column named salary.
#          They are looking for different salary range between 5000 and 8000

# %%
#import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.hist(salary_sample, bins = 10)
plt.title("The orignal range of the salary column")

#plt.label(x,y)-- to label my x/y axis
plt.xlabel("sal")
#plt.ylabel()
# Out:
# Text(0.5, 0, 'sal')

# %% [markdown]
# From the visualization: there are values which are out of desired range

# %%
#### Filtering method: Salaries which are greater than 8000 and less than 5000
np.random.seed(19680801)


# Filtering the values
salary_sample = salary_sample[(salary_sample['sal']>= 5000) & (salary_sample['sal']<= 8000)]


#and/or

# %%
salary_sample
# Out:
#     sal
# 0  5619
# 1  6083
# 3  6307
# 4  5440
# 8  5607

# %%
# %%time
sample1 = salary_sample.query('sal >= 5000') 
sample1
# Out:
# CPU times: user 2.16 ms, sys: 147 µs, total: 2.31 ms
# Wall time: 2.28 ms
#     sal
# 0  5619
# 1  6083
# 3  6307
# 4  5440
# 8  5607

# %%
salary_sample
# Out:
#     sal
# 0  5619
# 1  6083
# 3  6307
# 4  5440
# 8  5607

# %%
#import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.hist(salary_sample, bins = 10,range = [5000,8000])
plt.title("The filtered range of the salary column")

#y_lim = [y_min,y_mx]
#plt.y_limit()
# Out:
# Text(0.5, 1.0, 'The filtered range of the salary column')

# %% [markdown]
# **Another possible area of data range problem is incase of DATES

# %%
#Lets see an example of data range with the dates

#for()
#if conditon dupliucate
import numpy as np
import pandas as pd
dates = np.random.choice(pd.date_range(start='2000-01-01', end='2024-10-10'),
                         size=100)


sample_date = pd.DataFrame(dates, columns=['samp_date'])
sample_date.sample(10)
# Out:
#     samp_date
# 61 2024-01-03
# 10 2021-07-29
# 28 2016-01-05
# 33 2023-04-29
# 22 2003-10-02
# 14 2024-01-08
# 17 2014-10-23
# 42 2022-03-03
# 62 2022-04-20
# 30 2008-10-15

# %%
#to view the dimension of the data
sample_date.shape
# Out:
# (100, 1)

# %% [markdown]
# ##### For example:
#     Lets look at a Medical Insurance dataset
#     According to that the date:  "2021-10-28" is incorrect why???
#     Simple ans: **FUTURE DATE**

# %%
#**Wait a second: Keep in mind the data type 

#Method - 1
# Filtering the values
import datetime as dt

#Today's date
today = dt.date.today()
print(today)

#.loc()
#.iloc()

# sample_date = sample_date.loc[(sample_date['samp_date']) >pd.to_datetime(today)]
# print(sample_date)

#Method - 2
# Drop the date method: Dates which are greater than today's date
#drop the values
#row - axis = 1
# columns - axis = 0
#drop(axis = 1)

#.drop(columns = ['',''], axis= 0)


sample_date.drop(sample_date.loc[sample_date['samp_date'] > pd.to_datetime(today)].index, inplace = True)
print(sample_date)
# Out:
# 2024-06-06
#     samp_date
# 0  2003-11-29
# 1  2003-10-20
# 2  2017-02-13
# 3  2022-06-04
# 4  2024-04-10
# ..        ...
# 95 2019-09-26
# 96 2000-03-15
# 97 2014-09-17
# 98 2015-10-30
# 99 2019-07-08
#
# [99 rows x 1 columns]

# %% [markdown]
# ## Disclaimer: Be careful! Do not **MANIPULATE** data for your result gains
#
# ##### PLEASE ALWAYS KEEP DATA INTEGRITY!

# %%
#import matplotlib.pyplot as plt
plt.hist(data2['number_of_reviews'])
plt.show()

# %% [markdown]
# ##### 3) Duplicate Values
#
#
# Lets have a look at some feature which are pretty uninformative
#
# Any guesses?? ---> How to find out the duplicates?

# %% [markdown]
# ##### Lets understand the duplicates values from an example other than our data-set

# %%
#Create a dataframe
import pandas as pd

cars = {'Brand': ('Honda Civic','Toyota Corolla','Ford Focus','Audi A4','Lexus','Audi A4'),
        'Price': [22000,25000,27000,35000,20000,35000],
        'Color': ['Grey','Grey','White','Black','Blue','Black']
        }

df = pd.DataFrame(cars, columns = ['Brand', 'Price','Color'])
df
#set index as Brand
#df.set_index('Brand',inplace = True)
#df
# Out:
#             Brand  Price  Color
# 0     Honda Civic  22000   Grey
# 1  Toyota Corolla  25000   Grey
# 2      Ford Focus  27000  White
# 3         Audi A4  35000  Black
# 4           Lexus  20000   Blue
# 5         Audi A4  35000  Black

# %% [markdown]
# ##### Now we have atleast one culprit
# Lets check others by next techniques

# %%
#lets use .duplicated() method
#column_wise
col_duplicate = df.duplicated()
print(col_duplicate)


#row_wise
row_duplicate = df.duplicated()
df[row_duplicate]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool
#      Brand  Price  Color
# 5  Audi A4  35000  Black

# %%
#Method: To add new column to your DataFrame

#Series
Model_year = [2018,2018,2017,2020,2019,2020]

#Pandas method: to add new column to your dataFrame
df['Model_year'] = Model_year
df
#df['Name_of_col'] = data
# Out:
#             Brand  Price  Color  Model_year
# 0     Honda Civic  22000   Grey        2018
# 1  Toyota Corolla  25000   Grey        2018
# 2      Ford Focus  27000  White        2017
# 3         Audi A4  35000  Black        2020
# 4           Lexus  20000   Blue        2019
# 5         Audi A4  35000  Black        2020

# %% [markdown]
# **Using a "subset" attribute in .duplicated() method

# %%
#subset 1
#df_subset1_duplicate = df.duplicated(subset=['Color', 'Model_year'])
#print(df_subset1_duplicate)

#print(' ')

#subset 2
df_subset2_duplicate = df.duplicated(subset=['Color', 'Model_year'], keep = False)
df_subset2_duplicate
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# ##### Lets see if there are any duplicates in airbnb dataset

# %%
#lets use .duplicated() method
#column_wise
col_dup = data2.duplicated()
print(col_dup)

#row_wise
row_dup = data2.duplicated()
data2[row_dup]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10445    False
# 10446    False
# 10447    False
# 10448    False
# 10449    False
# Length: 10450, dtype: bool
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# We didn't get much valuable information
#
# What to do??

# %%
#Subset paramter

#Question: Remove the airbnb with same name and host_name and the price

duplicates = data2.duplicated( subset = [ 'host_name','neighbourhood','latitude','longitude'],  keep = False)
print(duplicates)
data2[duplicates]

#Now below observe there are some true values -> duplicated data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10445    False
# 10446    False
# 10447    False
# 10448    False
# 10449    False
# Length: 10450, dtype: bool
#              id                                               name    host_id  \
# 7         21126  Quiet Mid Century Modern Retreat with Patio an...      80406
# 14        39993                           Tiny Tarrytown Apartment     210965
# 16        46929                     Sunny Central Austin Apartment     210965
# 338      911955       Zilker House Comfortable Walkable 1930s Home    4893298
# 376      949054  ♥of Downtown w/free parking! Sleeps 10 in 7 be...     974631
# ...         ...                                                ...        ...
# 10429  46263425      Clean, cozy place of your own | 1BR in Austin  359036978
# 10439  46278968             Cozy apartment for you | 2BR in Austin  359036978
# ...

# %% [markdown]
# ###### How to remove duplicates using .drop_duplicates( )?

# %% [markdown]
# Lets look at the airbnb data_set

# %%
data_dup = data2.drop_duplicates()
data_dup
# Out:
#              id                                               name    host_id  \
# 0          2265   Zen-East in the Heart of Austin (monthly rental)       2466
# 1          5245  Eco friendly, Colorful, Clean, Cozy monthly share       2466
# 2          5456          Walk to 6th, Rainey St and Convention Ctr       8028
# 3          5636         Soco, Barton Springs Private Guest Cottage       7148
# 4          5769                                     NW Austin Room       8186
# ...         ...                                                ...        ...
# 10445  46281022      Locale | Rainey Street | 1BR Work from Locale    2370669
# 10446  46281034      Ideal Short Term Condo Location and Amenities     744383
# 10447  46281819                A place of your own | 1BR in Austin  359036978
# 10448  46281820           Entire apartment for you | 1BR in Austin  359036978
# 10449  46284246           Well-kept apartment home | 1BR in Austin  359036978
#
# ...

# %% [markdown]
# Lets remove the duplicates in a subset

# %%
#subset_df = df.drop_duplicates(subset=['Color','Model_year'], keep='first')
#subset_df

airbnb_values_data = data2.drop_duplicates(subset = ['name', 'host_name','price'])
airbnb_values_data
# Out:
#              id                                               name    host_id  \
# 0          2265   Zen-East in the Heart of Austin (monthly rental)       2466
# 1          5245  Eco friendly, Colorful, Clean, Cozy monthly share       2466
# 2          5456          Walk to 6th, Rainey St and Convention Ctr       8028
# 3          5636         Soco, Barton Springs Private Guest Cottage       7148
# 4          5769                                     NW Austin Room       8186
# ...         ...                                                ...        ...
# 10443  46279209                                   South Austin STR  158697924
# 10444  46279323  Wander to West 6th Renovated Clarksville with ...   50214619
# 10445  46281022      Locale | Rainey Street | 1BR Work from Locale    2370669
# 10446  46281034      Ideal Short Term Condo Location and Amenities     744383
# 10447  46281819                A place of your own | 1BR in Austin  359036978
#
# ...

# %%
#In this case lets assign the corrected data back to orignal dataframe


#Based on the following subset drop duplicates
data2[data2.duplicated(subset = ['host_id','host_name','name'] )]

#droping duplicates
data2 = data2.drop_duplicates(subset = ['host_id','host_name','name'])
data2
# Out:
#              id                                               name    host_id  \
# 0          2265   Zen-East in the Heart of Austin (monthly rental)       2466
# 1          5245  Eco friendly, Colorful, Clean, Cozy monthly share       2466
# 2          5456          Walk to 6th, Rainey St and Convention Ctr       8028
# 3          5636         Soco, Barton Springs Private Guest Cottage       7148
# 4          5769                                     NW Austin Room       8186
# ...         ...                                                ...        ...
# 10438  46277427             Affordable luxury 1BR APT -10min ATXDT  374574667
# 10443  46279209                                   South Austin STR  158697924
# 10444  46279323  Wander to West 6th Renovated Clarksville with ...   50214619
# 10445  46281022      Locale | Rainey Street | 1BR Work from Locale    2370669
# 10446  46281034      Ideal Short Term Condo Location and Amenities     744383
#
# ...

# %% [markdown]
# ##### 4) Missing Data

# %%
#data2.isna()

#Bird's Eye view of the dataset

data2.isnull().tail(20)
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 10415  False  False    False      False                 True          False
# 10416  False  False    False      False                 True          False
# 10417  False  False    False      False                 True          False
# 10418  False  False    False      False                 True          False
# 10423  False  False    False      False                 True          False
# 10424  False  False    False      False                 True          False
# 10426  False  False    False      False                 True          False
# 10430  False  False    False      False                 True          False
# 10431  False  False    False      False                 True          False
# 10432  False  False    False      False                 True          False
# 10433  False  False    False      False                 True          False
# ...

# %%
#To summarize na values
#axis - 0 --> row
#axis -1 --> column
data2.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            3
# neighbourhood_group               9782
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2204
# reviews_per_month                 2204
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
#visulaize the missing data 

# Calculate the percentage of missing values in each column
missing_percentage = data2.isnull().mean() * 100

# Identify columns with only missing values
columns_with_only_missing = missing_percentage[missing_percentage >= 0.5].index
print(columns_with_only_missing)

# Create the missing data visualization
msno.bar(data2, color='dodgerblue', fontsize=12, figsize=(10, 6), labels=True)

# Set plot title and axis labels
plt.title('Missing Data Visualization', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Missing Data Percentage', fontsize=12)

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Index(['neighbourhood_group', 'last_review', 'reviews_per_month'], dtype='object')

# %%
#data2.info()

# %%
#Now if we want to examine a particular column for a missing value
data2[data2['host_name'].isnull()]
# Out:
#             id                                             name   host_id  \
# 1033   4356661                 1 BR 1 Bath DT Apt [W/D in unit]  21791967
# 1768   8214182              Private room  in all female housing  21556779
# 5465  27025549  Studio apt in prime central Austin free parking   9390873
#
#      host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 1033       NaN                  NaN          78704     30.26     -97.75
# 1768       NaN                  NaN          78741     30.23     -97.73
# 5465       NaN                  NaN          78731     30.31     -97.76
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 1033  Entire home/apt     75               1                  1  2015-08-13
# 1768     Private room     27               1                  4  2015-09-24
# 5465  Entire home/apt     46               2                 10  2020-10-25
#
# ...

# %% [markdown]
# #### MAIN QUESTION----> HOW TO TREAT THESE MISSING VALUES???

# %% [markdown]
# ##### 4.1) Drop the missing values:

# %%
data2.shape
# Out:
# (9782, 16)

# %%
#Lets drop the NAN values
#Please do not run this function. It is for explanation purposes only.

#data2.dropna().shape

# %%
#Lets get rid of the neighbourhood_group column
data2.drop(columns = 'neighbourhood_group', axis = 1,inplace = True)

# %%
data2.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            3
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2204
# reviews_per_month                 2204
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# ##### 4.2) Fill the na values method

# %%
data2.reviews_per_month
# Out:
# 0       0.17
# 1       0.06
# 2       3.78
# 3       0.14
# 4       2.00
#         ...
# 10438    NaN
# 10443    NaN
# 10444    NaN
# 10445    NaN
# 10446    NaN
# Name: reviews_per_month, Length: 9782, dtype: float64

# %%
#Lets use fillna() with 0
data2['reviews_per_month']= data2['reviews_per_month'].fillna(0.00)


#data2.reviews_per_month

# %%
#OPTIONAL STEP: QUICK CHECK 
#data2.isna().sum()

# %%
#Lets fill NaN's of host_name with 'unknown'

data2[data2.host_name.isnull()]

# Fill missing names with a specific value
data2['host_name'].fillna('Unknown',inplace = True)

# %%
#Fill Missing Dates with a Specific Value

#checking the rows where there are missing data
data2[data2.last_review.isna() == True]

# Fill missing dates
data2['last_review'] = pd.to_datetime(data2['last_review'].fillna(0))

# %%
#Evidence of no missing values
#data2.isnull().sum()

# %%
#exporting the csv file to parquet format
data2.to_parquet('clean_file1.parquet',index = False)
