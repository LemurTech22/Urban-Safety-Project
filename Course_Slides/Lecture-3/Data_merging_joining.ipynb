# %% [markdown]
# ### 1. concatenate              2. merge                        3. join

# %%
import pandas as pd
import numpy as np

# %%
#created dummy data using the dictionary data structure in python
toy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Col_1': ['A', 'C', 'E', 'G', 'I'],
        'Col_2': ['B', 'D', 'F', 'H', 'J']}

# %%
df1 = pd.DataFrame(toy_data1)

# %%
df1
# Out:
#   id Col_1 Col_2
# 0  1     A     B
# 1  2     C     D
# 2  3     E     F
# 3  4     G     H
# 4  5     I     J

# %%
toy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Col_1': ['K', 'M', 'O', 'Q', 'S'],
        'Col_2': ['L', 'N', 'P', 'R', 'T']}
df2 = pd.DataFrame(toy_data2)

df2
# Out:
#   id Col_1 Col_2
# 0  1     K     L
# 1  2     M     N
# 2  6     O     P
# 3  7     Q     R
# 4  8     S     T

# %%
toy_data3 = {
        'id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'Col_3': [12, 13, 14, 15, 16, 17, 15, 12, 13, 23]}
df3 = pd.DataFrame(toy_data3, columns = ['id', 'Col_3'])

df3
# Out:
#    id  Col_3
# 0   1     12
# 1   2     13
# 2   3     14
# 3   4     15
# 4   5     16
# 5   7     17
# 6   8     15
# 7   9     12
# 8  10     13
# 9  11     23

# %% [markdown]
# How to Concatenate the df1 and df2?

# %%
concated_data_row = pd.concat(df1,df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c7a53e99136c> in <module>
# ----> 1 concated_data_row = pd.concat(df1,df2)
#       2
#       3 #df_row = pd.concat([df1, df2])
#       4
#       5 #df_row
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     304     ):
#     305         if isinstance(objs, (NDFrame, str)):
# --> 306             raise TypeError(
# ...

# %%
concated_data_row = pd.concat([df1, df2])
concated_data_row
# Out:
#   id Col_1 Col_2
# 0  1     A     B
# 1  2     C     D
# 2  3     E     F
# 3  4     G     H
# 4  5     I     J
# 0  1     K     L
# 1  2     M     N
# 2  6     O     P
# 3  7     Q     R
# 4  8     S     T

# %% [markdown]
# Can you spot an issue ?

# %%
concated_data_row = pd.concat([df1, df2], ignore_index=True)
concated_data_row
# Out:
#   id Col_1 Col_2
# 0  1     A     B
# 1  2     C     D
# 2  3     E     F
# 3  4     G     H
# 4  5     I     J
# 5  1     K     L
# 6  2     M     N
# 7  6     O     P
# 8  7     Q     R
# 9  8     S     T

# %%
#concatenate along the columns
#concated_data_col = pd.concat([df1,df2], axis=1)

#concated_data_col


#how to ignore the other id col?

drop_duplicate_id = concated_data_col.drop(columns=['id'], axis =1)
drop_duplicate_id

#solution

#rename the columns and then drop the renamed column
concated_data_col.rename(columns = {"id":"id1","id":"id2"})
# Out:
#   id2 Col_1 Col_2 id2 Col_1 Col_2
# 0   1     A     B   1     K     L
# 1   2     C     D   2     M     N
# 2   3     E     F   6     O     P
# 3   4     G     H   7     Q     R
# 4   5     I     J   8     S     T

# %% [markdown]
# How to do Merging?

# %%
df_merge_col = pd.merge(concated_data_row, df3, on='id')

df_merge_col
# Out:
#   id Col_1 Col_2  Col_3
# 0  1     A     B     12
# 1  1     K     L     12
# 2  2     C     D     13
# 3  2     M     N     13
# 4  3     E     F     14
# 5  4     G     H     15
# 6  5     I     J     16
# 7  7     Q     R     17
# 8  8     S     T     15

# %%
#outer join
df_outer = pd.merge(df1, df2, on='id', how='outer')
#suffixes=('_left','_right')
df_outer
# Out:
#   id Col_1_left Col_2_left Col_1_right Col_2_right
# 0  1          A          B           K           L
# 1  2          C          D           M           N
# 2  3          E          F         NaN         NaN
# 3  4          G          H         NaN         NaN
# 4  5          I          J         NaN         NaN
# 5  6        NaN        NaN           O           P
# 6  7        NaN        NaN           Q           R
# 7  8        NaN        NaN           S           T

# %%
df1
# Out:
#   id Col_1 Col_2
# 0  1     A     B
# 1  2     C     D
# 2  3     E     F
# 3  4     G     H
# 4  5     I     J

# %%
df2
# Out:
#   id Col_1 Col_2
# 0  1     K     L
# 1  2     M     N
# 2  6     O     P
# 3  7     Q     R
# 4  8     S     T

# %% [markdown]
# FULL OUTER JOIN:
#
# -Combines the results of both the left and the right outer joins
#
# -The joined DataFrame contain all records from both the DataFrames
#
# -Fill in NaNs for missing matches on either side

# %%
#inner join
df_inner = pd.merge(df1, df2, on='id', how='inner')

df_inner
# Out:
#   id Col_1_x Col_2_x Col_1_y Col_2_y
# 0  1       A       B       K       L
# 1  2       C       D       M       N

# %% [markdown]
# INNER JOIN:
#
# -Produces only the set of records that match in both DataFrame A and DataFrame B.

# %%
df_right = pd.merge(df1, df2, on='id', how='right')

#left_on='id',right_on='id'

df_right
# Out:
#   id Col_1_x Col_2_x Col_1_y Col_2_y
# 0  1       A       B       K       L
# 1  2       C       D       M       N
# 2  6     NaN     NaN       O       P
# 3  7     NaN     NaN       Q       R
# 4  8     NaN     NaN       S       T

# %%
df_left = pd.merge(df1, df2, on='id', how='left')

df_left
# Out:
#   id Col_1_x Col_2_x Col_1_y Col_2_y
# 0  1       A       B       K       L
# 1  2       C       D       M       N
# 2  3       E       F     NaN     NaN
# 3  4       G       H     NaN     NaN
# 4  5       I       J     NaN     NaN

# %% [markdown]
# Right Join:
#
# -produces a complete set of records from DataFrame B (right DataFrame), with the matching records (where available) in DataFrame A (left DataFrame)
#
#
# Left Join:
#
# -Produces a complete set of records from DataFrame A (left DataFrame),with the matching records (where available) in DataFrame B (right DataFrame)
#
#
# Result:
#
# -If there is no match, the respective side will contain NAN values

# %%
#merge on index
df_index = pd.merge(df1, df2, right_index=True, left_index=True)

df_index
# Out:
#   id_x Col_1_x Col_2_x id_y Col_1_y Col_2_y
# 0    1       A       B    1       K       L
# 1    2       C       D    2       M       N
# 2    3       E       F    6       O       P
# 3    4       G       H    7       Q       R
# 4    5       I       J    8       S       T
